# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ## **`Reading the csv file`**

# %%
Data_frame = pd.read_csv("/gdrive/MyDrive/Pattern/Bladder_cancer/bladder_cancer.csv")

# %% [markdown]
# ## **`Viewing DataFrame`**

# %%
Data_frame.head()
# Out:
#    A/G Ratio  Albumin    Alk  ALT (GPT)  AST (GOT)    BUN  Calcium  Chloride  \
# 0        NaN      3.9   53.0       28.0       25.0   11.0      NaN     107.0
# 1        NaN      3.2   87.0       14.0       26.0    9.8      NaN     101.8
# 2        NaN      4.4   69.0       28.0       16.0   21.0      8.5     100.0
# 3        NaN      NaN    NaN       18.0       24.0   11.0      NaN     103.9
# 4        NaN      4.1  175.0       34.0       66.0  184.0      7.4     110.0
#
#    Creatinine  Direct Bilirubin  ...   age  gender  Hyper1en1ion  Diabe1es  \
# 0        0.60               0.1  ...  72.0     0.0             0         0
# 1        0.60               0.1  ...  74.0     0.0             0         0
# 2        1.40               0.2  ...  69.0     1.0             1         1
# 3        0.96               NaN  ...  69.0     1.0             0         0
# 4        3.10               0.2  ...  69.0     1.0             1         1
#
#    Smoking  Drinking  Bee1leNu1  FamilyHis1ory   Disease  Patient Number
# 0        0         0          0              0  Cystitis          222159
# 1        0         0          0              0  Cystitis          397523
# 2        0         0          0              0  Cystitis          556667
# 3        0         1          0              0  Cystitis          567311
# 4        0         0          0              0  Cystitis         1194899
#
# [5 rows x 41 columns]

# %% [markdown]
# ## **`Checking the columns`**

# %%
Data_frame.columns
# Out:
# Index(['A/G Ratio', 'Albumin', 'Alk', 'ALT (GPT)', 'AST (GOT)', 'BUN',
#        'Calcium', 'Chloride', 'Creatinine', 'Direct Bilirubin',
#        'Estimated GFR', 'Glucose AC', 'Nitrite', 'Urine occult Blood', 'pH',
#        'Potassium', 'Sodium', 'Specific Gravity', 'Strip WBC',
#        'Total Bilirubin', 'Total Cholesterol', 'Total Protein', 'Triglyceride',
#        'Urine epitheilum (UL)', 'Urine epithelium count', 'Uric acid',
#        'Urine Bilirubin', 'Urine Glucose', 'Urine Ketone', 'Urine Protein',
#        'Urobilinogen', 'age', 'gender', 'Hyper1en1ion', 'Diabe1es', 'Smoking',
#        'Drinking', 'Bee1leNu1', 'FamilyHis1ory', 'Disease', 'Patient Number'],
#       dtype='object')

# %% [markdown]
# ## **`Cheking the datatypes of the columns`**

# %%
Data_frame.dtypes
# Out:
# A/G Ratio                 float64
# Albumin                   float64
# Alk                       float64
# ALT (GPT)                 float64
# AST (GOT)                 float64
# BUN                       float64
# Calcium                   float64
# Chloride                  float64
# Creatinine                float64
# Direct Bilirubin          float64
# Estimated GFR             float64
# Glucose AC                float64
# Nitrite                   float64
# Urine occult Blood        float64
# pH                        float64
# Potassium                 float64
# Sodium                    float64
# Specific Gravity          float64
# Strip WBC                 float64
# Total Bilirubin           float64
# Total Cholesterol         float64
# Total Protein             float64
# Triglyceride              float64
# Urine epitheilum (UL)     float64
# Urine epithelium count    float64
# Uric acid                 float64
# Urine Bilirubin           float64
# Urine Glucose             float64
# Urine Ketone              float64
# Urine Protein             float64
# Urobilinogen              float64
# age                       float64
# gender                    float64
# Hyper1en1ion                int64
# Diabe1es                    int64
# Smoking                     int64
# Drinking                    int64
# Bee1leNu1                   int64
# FamilyHis1ory               int64
# Disease                    object
# Patient Number              int64
# dtype: object

# %% [markdown]
# ## **`Cheking if NaN value exists`**

# %%
len(Data_frame)
# Out:
# 1336

# %%
Data_frame.isna().sum()
# Out:
# A/G Ratio                 590
# Albumin                   300
# Alk                       506
# ALT (GPT)                  91
# AST (GOT)                  62
# BUN                        25
# Calcium                   572
# Chloride                  113
# Creatinine                  7
# Direct Bilirubin          405
# Estimated GFR              12
# Glucose AC                 52
# Nitrite                    36
# Urine occult Blood         36
# pH                         36
# Potassium                  48
# Sodium                     50
# Specific Gravity           36
# Strip WBC                 215
# Total Bilirubin           289
# Total Cholesterol         260
# Total Protein             382
# Triglyceride              273
# Urine epitheilum (UL)     575
# Urine epithelium count     36
# Uric acid                 212
# Urine Bilirubin            36
# Urine Glucose             221
# Urine Ketone              222
# Urine Protein              36
# Urobilinogen               36
# age                         3
# gender                      3
# Hyper1en1ion                0
# Diabe1es                    0
# Smoking                     0
# Drinking                    0
# Bee1leNu1                   0
# FamilyHis1ory               0
# Disease                     0
# Patient Number              0
# dtype: int64

# %%
def fill_values(column, column_type):
  if column_type == "Categorical":
    mid = Data_frame[column].median()
    Data_frame[column].fillna(mid, inplace = True)
  if column_type == "Continuous":
    mean = Data_frame[column].mean()
    Data_frame[column].fillna(mean, inplace = True)

# %%
column_and_types = [
    ["A/G Ratio", "Continuous"],
    ["Albumin", "Continuous"],
    ["Alk", "Continuous"],
    ["ALT (GPT)", "Continuous"],
    ["AST (GOT)", "Continuous"],
    ["BUN", "Continuous"],
    ["Calcium", "Continuous"],
    ["Chloride", "Continuous"],
    ["Creatinine", "Continuous"],
    ["Direct Bilirubin", "Continuous"],
    ["Estimated GFR", "Continuous"],
    ["Glucose AC", "Continuous"],
    ["pH", "Continuous"],
    ["Potassium", "Continuous"],
    ["Sodium", "Continuous"],
    ["Specific Gravity", "Continuous"],
    ["Strip WBC", "Continuous"],
    ["Total Bilirubin", "Continuous"],
    ["Total Cholesterol", "Continuous"],
    ["Total Protein", "Continuous"],
    ["Triglyceride", "Continuous"],
    ["Urine epitheilum (UL)", "Continuous"],
    ["Urine epithelium count", "Continuous"],
    ["Uric acid", "Continuous"],
    ["Urine Bilirubin", "Categorical"],
    ["Urine Glucose", "Categorical"],
    ["Urine Ketone", "Categorical"],
    ["Urine Protein", "Categorical"],
    ["Urobilinogen", "Categorical"],
    ["Nitrite", "Categorical"],
    ["Urine occult Blood", "Categorical"],
    ["age", "Categorical"],
    ["gender", "Categorical"]
]

# %%
for i in range(len(column_and_types)):
  fill_values(column_and_types[i][0], column_and_types[i][1])

# %%
Data_frame.isna().sum()
# Out:
# A/G Ratio                 0
# Albumin                   0
# Alk                       0
# ALT (GPT)                 0
# AST (GOT)                 0
# BUN                       0
# Calcium                   0
# Chloride                  0
# Creatinine                0
# Direct Bilirubin          0
# Estimated GFR             0
# Glucose AC                0
# Nitrite                   0
# Urine occult Blood        0
# pH                        0
# Potassium                 0
# Sodium                    0
# Specific Gravity          0
# Strip WBC                 0
# Total Bilirubin           0
# Total Cholesterol         0
# Total Protein             0
# Triglyceride              0
# Urine epitheilum (UL)     0
# Urine epithelium count    0
# Uric acid                 0
# Urine Bilirubin           0
# Urine Glucose             0
# Urine Ketone              0
# Urine Protein             0
# Urobilinogen              0
# age                       0
# gender                    0
# Hyper1en1ion              0
# Diabe1es                  0
# Smoking                   0
# Drinking                  0
# Bee1leNu1                 0
# FamilyHis1ory             0
# Disease                   0
# Patient Number            0
# dtype: int64

# %% [markdown]
# ## **`Dropping Patient Number column`**

# %%
Final_Data_frame = Data_frame.drop("Patient Number", axis=1)

# %% [markdown]
# ## **`Integer encoding of the labels`**

# %%
def integer_encoding(Data_frame, column):
  from sklearn import preprocessing
  label = preprocessing.LabelEncoder()
  label.fit(Data_frame[column])
  Labels = label.transform(Data_frame[column])
  Classes = label.classes_
  return Labels, Classes

# %% [markdown]
# ## **`Label encoding according to need`**

# %%
def label_encoding(Data_frame, column, class1, class2):
  labels = []
  for i in range(len(Data_frame)):
    if Data_frame.iloc[i][column] == class1:
      labels.append(0)
    else:
      labels.append(1)
  classes = np.unique(Data_frame["Disease"])
  # classes = np.flip(classes)
  return np.array(labels), classes

# %% [markdown]
# ## **`Shuffling the dataset`**

# %%
def shuffle(Final_Data_frame): 
  np.random.seed(10)
  Final_Data_frame = Final_Data_frame.sample(frac=1)
  Final_Data_frame = Final_Data_frame.reset_index(drop=True)
  return Final_Data_frame

# %% [markdown]
# ## **`Splitting train and test data`**

# %%
def splitting(X, Y):
  from sklearn.model_selection import train_test_split
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.8, random_state=53, stratify=Y)
  # print(f"Training samples: {len(X_train)}")
  # print(f"Testing samples: {len(X_test)}")
  return X_train, X_test, Y_train, Y_test

# %% [markdown]
# ## **`Accuracy score`**

# %%
def Accuracy(Y_test, Y_pred, suffix=None):
  from sklearn.metrics import accuracy_score
  Accuracy = accuracy_score(Y_test, Y_pred)
  Accuracy = round(Accuracy, 3)*100
  print(f"{suffix}'s accuracy: {Accuracy}%")  
  return Accuracy

# %% [markdown]
# ## **`Classification report`**

# %%
def classification_report(Y_test, Y_pred, Classes, suffix=None):
  from sklearn.metrics import classification_report
  C_r = classification_report(Y_test, Y_pred, target_names = Classes)
  print(f"{suffix}'s classification report: \n{C_r}")

# %% [markdown]
# ## **`Confusion matrix`**

# %%
def confusion_matrix(Y_test, Y_pred, Classes, suffix=None):

  from sklearn.metrics import confusion_matrix
  import seaborn as sns

  C_m = confusion_matrix(Y_test, Y_pred)
  Cm_Df = pd.DataFrame(C_m, index = Classes, columns = Classes)

  print(f"{suffix}'s confusion matrix: \n")

  fig, ax = plt.subplots(figsize = (5,5))

  ax = sns.heatmap(
      Cm_Df,
      cbar = False,
      cmap = "gnuplot",
      annot = True,
      linewidth = 3,
      annot_kws = {
          'fontsize' : 15
      },
      fmt="d"
  )

  plt.suptitle(f"Confusion matrix for {suffix}", fontsize=20)
  plt.suptitle(f"{suffix}", fontsize=15, color = 'purple',fontweight="bold")
  plt.xlabel("Actual Values", fontsize=15)
  plt.ylabel("Predicted Values", fontsize=15)

# %% [markdown]
# ## **`Model evaluation`**

# %%
def model_evaluation(Y_true, Y_pred, Labels, suffix):

  Accuracy(Y_true, Y_pred, suffix)
  print("\n")
  classification_report(Y_true, Y_pred, Labels, suffix)
  print("\n")
  # confusion_matrix(Y_true, Y_pred, Labels, suffix)

# %% [markdown]
# ## **`ROC-AUC Curve`**

# %%
def roc_auc(Y_test, positive_probs_dt, positive_probs_rf, positive_probs_lgbtm):
  from sklearn.metrics import roc_curve 
  from sklearn.metrics import roc_auc_score

  fpr_dt, tpr_dt, thresholds_dt = roc_curve(Y_test, positive_probs_dt)
  score_dt = round(roc_auc_score(Y_test, positive_probs_dt), 4)

  fpr_rf, tpr_rf, thresholds_rf = roc_curve(Y_test, positive_probs_rf)
  score_rf = round(roc_auc_score(Y_test, positive_probs_rf), 4)

  fpr_lgbtm, tpr_lgbtm, thresholds_lgbtm = roc_curve(Y_test, positive_probs_lgbtm)
  score_lgbtm = round(roc_auc_score(Y_test, positive_probs_lgbtm), 4)

  plt.figure(figsize=(9,9))
  plt.plot(fpr_dt, tpr_dt, color="red", linestyle = "--", label = "Decision Tree | AUC: {score}".format(score=score_dt))
  plt.plot(fpr_rf, tpr_rf, color="green", linestyle = "-.", label = "Random Forest | AUC: {score}".format(score=score_rf))
  plt.plot(fpr_lgbtm, tpr_lgbtm, color="blue", linestyle = ":", label = "LightGBM | AUC: {score}".format(score=score_lgbtm))

  plt.xlabel("False Positive Rate (fpr)", fontsize=12)
  plt.ylabel("True Positive rate (tpr)", fontsize=12)
  plt.title("ROC curve for Cystitis vs Bladder cancer", fontsize=15)
  plt.legend(loc="lower right")
  plt.show()

# %% [markdown]
# ## **`Classifiers`**
# * `Decision tree`
# * `Random forest`
# * `LightGBM`

# %% [markdown]
# ## **`Decision tree`**

# %%
def Decision_tree(X_train, Y_train, Y_test, Classes): 
    
  from sklearn import tree
  classifier = tree.DecisionTreeClassifier(
      criterion = "gini",
      max_depth = 4,
      random_state = 53
  )
  classifier = classifier.fit(X_train, Y_train)
  Y_pred = classifier.predict(X_test)
  Y_pred_proba = classifier.predict_proba(X_test)
  model_evaluation(Y_test, Y_pred, Classes, suffix="Decision tree")
  acc = Accuracy(Y_test, Y_pred, suffix="Decision tree")

  return classifier, Y_pred, Y_pred_proba, acc

# %% [markdown]
# ## **`Random Forest`**

# %%
def Random_forest(X_train, Y_train, Y_test, Classes): 
    
  from sklearn.ensemble import RandomForestClassifier

  classifier = RandomForestClassifier(
        criterion = "gini",
        n_estimators = 300,
        random_state = 53
    )
  
  classifier = classifier.fit(X_train, Y_train)
  Y_pred = classifier.predict(X_test)
  Y_pred_proba = classifier.predict_proba(X_test)
  model_evaluation(Y_test, Y_pred, Classes, suffix="Random Forest")
  acc = Accuracy(Y_test, Y_pred, suffix="Random Forest")

  return classifier, Y_pred, Y_pred_proba, acc

# %% [markdown]
# ## **`Light Gradient Boosting Machine (LightGBM)`**

# %%
def Lgbtm(X_train, Y_train, Y_test, Classes): 
    
  from lightgbm import LGBMClassifier
  classifier = LGBMClassifier(
      max_depth = 1,
      num_leaves  = 100,
      random_state = 50
  )
  
  classifier = classifier.fit(X_train, Y_train)
  Y_pred = classifier.predict(X_test)
  Y_pred_proba = classifier.predict_proba(X_test)
  model_evaluation(Y_test, Y_pred, Classes, suffix="LightGBM")
  acc = Accuracy(Y_test, Y_pred, suffix="LightGBM")

  return classifier, Y_pred, Y_pred_proba, acc

# %%
def pearson_correlation(X, threshold):
  import seaborn as sns
  col_corr = set()
  corr_matrix = X.corr()
  # plt.figure(figsize=(50,50))
  # sns.heatmap(corr_matrix, annot=True, cmap=plt.cm.Accent_r)
  # plt.show()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if (abs(corr_matrix.iloc[i,j])) > threshold:
        colname = corr_matrix.columns[i]
        col_corr.add(colname)
  return col_corr

# %%
np.unique(Data_frame["Disease"])
# Out:
# array(['Cystitis', 'Kidney', 'Prostate', 'UrinaryBladder', 'Uterus'],
#       dtype=object)

# %% [markdown]
# ## **`Bladder vs Cystitis`**

# %%
class0 = "Cystitis"
class1 = "UrinaryBladder"

# %% [markdown]
# ## **`Number of rows for each class`**

# %%
uterus = Data_frame[Data_frame["Disease"] == class0]
bladder = Data_frame[Data_frame["Disease"] == class1]
print("Number of rows for ")
print(f"\tCystitis cancer: {len(uterus)}")
print(f"\tBladder cancer: {len(bladder)}")
# Out:
# Number of rows for
# 	Cystitis cancer: 144
# 	Bladder cancer: 591

# %%
cancers = [class0 , class1]
BvsU = Final_Data_frame[Final_Data_frame["Disease"].isin(cancers)]
BvsU = shuffle(BvsU)
X = BvsU.drop("Disease", axis=1)
Y, classes = label_encoding(BvsU, "Disease", class0, class1)
X_train, X_test, Y_train, Y_test = splitting(X, Y)

# %%
decision_tree, Y_pred_dt, Y_pred_proba_dt, _ = Decision_tree(X_train, Y_train, Y_test, classes)
positive_probs_dt = Y_pred_proba_dt[:,1]
# Out:
# Decision tree's accuracy: 99.3%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.97      1.00      0.98        29
# UrinaryBladder       1.00      0.99      1.00       118
#
#       accuracy                           0.99       147
#      macro avg       0.98      1.00      0.99       147
#   weighted avg       0.99      0.99      0.99       147
#
#
#
# Decision tree's accuracy: 99.3%

# %%
random_forest, Y_pred_rf, Y_pred_proba_rf, _ = Random_forest(X_train, Y_train, Y_test, classes)
positive_probs_rf = Y_pred_proba_rf[:,1]
# Out:
# Random Forest's accuracy: 96.6%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.96      0.86      0.91        29
# UrinaryBladder       0.97      0.99      0.98       118
#
#       accuracy                           0.97       147
#      macro avg       0.96      0.93      0.94       147
#   weighted avg       0.97      0.97      0.97       147
#
#
#
# Random Forest's accuracy: 96.6%

# %%
lgbtm, Y_pred_rf, Y_pred_proba_lgbtm, _ = Lgbtm(X_train, Y_train, Y_test, classes)
positive_probs_lgbtm = Y_pred_proba_lgbtm[:,1]
# Out:
# LightGBM's accuracy: 99.3%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.97      1.00      0.98        29
# UrinaryBladder       1.00      0.99      1.00       118
#
#       accuracy                           0.99       147
#      macro avg       0.98      1.00      0.99       147
#   weighted avg       0.99      0.99      0.99       147
#
#
#
# LightGBM's accuracy: 99.3%

# %%
roc_auc(Y_test, positive_probs_dt, positive_probs_rf, positive_probs_lgbtm)

# %% [markdown]
# ## **`Pearson correlation`**

# %%
def pearson_correlation(X, threshold):
  import seaborn as sns
  col_corr = set()
  corr_matrix = X.corr()
  # plt.figure(figsize=(50,30))
  # sns.heatmap(corr_matrix, annot=True, cmap=plt.cm.Accent_r)
  # plt.show()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if (abs(corr_matrix.iloc[i,j])) > threshold:
        colname = corr_matrix.columns[i]
        col_corr.add(colname)
  return col_corr

# %% [markdown]
# ## **`Threshold value for correlation`**

# %%
Threshold = 0.2 #@param{type:"slider", min:0.1, max:1.0, step:0.1}

# %%
correlated_features = pearson_correlation(X, Threshold)
print(f"\nCorrelated columns: {correlated_features}")
print("\n")
X_pear = X.drop(correlated_features, axis=1)
print(f"Remaining columns: {X_pear.columns}\n")

X_train, X_test, Y_train, Y_test = splitting(X_pear, Y)

# Ideal threshold value = 0.2 
_, _, Y_pred_proba_dt, _ = Decision_tree(X_train, Y_train, Y_test, classes)
positive_probs_dt = Y_pred_proba_dt[:,1]

# Ideal threshold value = 0.2
_, _, Y_pred_proba_dt, _ = Random_forest(X_train, Y_train, Y_test, classes)
positive_probs_rf = Y_pred_proba_dt[:,1]

# Ideal threshold value = 0.2
_, _, Y_pred_proba_dt, _ = Lgbtm(X_train, Y_train, Y_test, classes)
positive_probs_lgbtm = Y_pred_proba_dt[:,1]

roc_auc(Y_test, positive_probs_dt, positive_probs_rf, positive_probs_lgbtm)
# Out:
# Correlated columns: {'Calcium', 'FamilyHis1ory', 'Uric acid', 'Diabe1es', 'gender', 'Strip WBC', 'Urine Ketone', 'Albumin', 'Urine Glucose', 'Urine Protein', 'Hyper1en1ion', 'Total Protein', 'Total Bilirubin', 'Chloride', 'Creatinine', 'Potassium', 'Bee1leNu1', 'Alk', 'Sodium', 'Total Cholesterol', 'Drinking', 'Urine epithelium count', 'age', 'Smoking', 'Estimated GFR'}
#
#
# Remaining columns: Index(['A/G Ratio', 'ALT (GPT)', 'AST (GOT)', 'BUN', 'Direct Bilirubin',
#        'Glucose AC', 'Nitrite', 'Urine occult Blood', 'pH', 'Specific Gravity',
#        'Triglyceride', 'Urine epitheilum (UL)', 'Urine Bilirubin',
#        'Urobilinogen'],
#       dtype='object')
#
# Decision tree's accuracy: 99.3%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.97      1.00      0.98        29
# UrinaryBladder       1.00      0.99      1.00       118
#
#       accuracy                           0.99       147
#      macro avg       0.98      1.00      0.99       147
#   weighted avg       0.99      0.99      0.99       147
#
#
#
# Decision tree's accuracy: 99.3%
# Random Forest's accuracy: 99.3%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.97      1.00      0.98        29
# UrinaryBladder       1.00      0.99      1.00       118
#
#       accuracy                           0.99       147
#      macro avg       0.98      1.00      0.99       147
#   weighted avg       0.99      0.99      0.99       147
#
#
#
# Random Forest's accuracy: 99.3%
# LightGBM's accuracy: 99.3%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.97      1.00      0.98        29
# UrinaryBladder       1.00      0.99      1.00       118
#
#       accuracy                           0.99       147
#      macro avg       0.98      1.00      0.99       147
#   weighted avg       0.99      0.99      0.99       147
#
#
#
# LightGBM's accuracy: 99.3%

# %% [markdown]
# ## **`Principal Component Analysis (PCA)`**

# %%
def pca(X, components):
  from sklearn import decomposition
  pcs = decomposition.PCA(n_components = components)
  pcs.fit(X)
  X_pca = pcs.transform(X)  
  return X_pca

# %%
dt_val = []
rf_val= []
lgbtm_val = []
for i in range(2, len(X.columns)):
  print(f"For {i} features: ")
  X_pca = pca(X, i)
  X_train, X_test, Y_train, Y_test = splitting(X_pca, Y)
  _, _, _, dt = Decision_tree(X_train, Y_train, Y_test, classes)
  _, _, _, r__f = Random_forest(X_train, Y_train, Y_test, classes)
  _, _, _, lgb__tm = Lgbtm(X_train, Y_train, Y_test, classes)
  dt_val.append(dt)
  rf_val.append(r__f)
  lgbtm_val.append(lgb__tm)
# Out:
# For 2 features:
# Decision tree's accuracy: 78.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.20      0.03      0.06        29
# UrinaryBladder       0.80      0.97      0.88       118
#
#       accuracy                           0.78       147
#      macro avg       0.50      0.50      0.47       147
#   weighted avg       0.68      0.78      0.72       147
#
#
#
# Decision tree's accuracy: 78.2%
# Random Forest's accuracy: 73.5%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.14      0.07      0.09        29
# UrinaryBladder       0.80      0.90      0.84       118
#
#       accuracy                           0.73       147
#      macro avg       0.47      0.48      0.47       147
#   weighted avg       0.67      0.73      0.70       147
#
#
#
# Random Forest's accuracy: 73.5%
# LightGBM's accuracy: 80.30000000000001%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.80      1.00      0.89       118
#
#       accuracy                           0.80       147
#      macro avg       0.40      0.50      0.45       147
#   weighted avg       0.64      0.80      0.71       147
#
#
#
# LightGBM's accuracy: 80.30000000000001%
# For 3 features:
# Decision tree's accuracy: 78.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.20      0.03      0.06        29
# UrinaryBladder       0.80      0.97      0.88       118
#
#       accuracy                           0.78       147
#      macro avg       0.50      0.50      0.47       147
#   weighted avg       0.68      0.78      0.72       147
#
#
#
# Decision tree's accuracy: 78.2%
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest's accuracy: 74.8%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.10      0.03      0.05        29
# UrinaryBladder       0.80      0.92      0.85       118
#
#       accuracy                           0.75       147
#      macro avg       0.45      0.48      0.45       147
#   weighted avg       0.66      0.75      0.70       147
#
#
#
# Random Forest's accuracy: 74.8%
# LightGBM's accuracy: 80.30000000000001%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.80      1.00      0.89       118
#
#       accuracy                           0.80       147
#      macro avg       0.40      0.50      0.45       147
#   weighted avg       0.64      0.80      0.71       147
#
#
#
# LightGBM's accuracy: 80.30000000000001%
# For 4 features:
# Decision tree's accuracy: 76.9%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.14      0.03      0.06        29
# UrinaryBladder       0.80      0.95      0.87       118
#
#       accuracy                           0.77       147
#      macro avg       0.47      0.49      0.46       147
#   weighted avg       0.67      0.77      0.71       147
#
#
#
# Decision tree's accuracy: 76.9%
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest's accuracy: 76.9%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.22      0.07      0.11        29
# UrinaryBladder       0.80      0.94      0.87       118
#
#       accuracy                           0.77       147
#      macro avg       0.51      0.50      0.49       147
#   weighted avg       0.69      0.77      0.72       147
#
#
#
# Random Forest's accuracy: 76.9%
# LightGBM's accuracy: 80.30000000000001%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.80      1.00      0.89       118
#
#       accuracy                           0.80       147
#      macro avg       0.40      0.50      0.45       147
#   weighted avg       0.64      0.80      0.71       147
#
#
#
# LightGBM's accuracy: 80.30000000000001%
# For 5 features:
# Decision tree's accuracy: 77.60000000000001%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.80      0.97      0.87       118
#
#       accuracy                           0.78       147
#      macro avg       0.40      0.48      0.44       147
#   weighted avg       0.64      0.78      0.70       147
#
#
#
# Decision tree's accuracy: 77.60000000000001%
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest's accuracy: 78.2%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.33      0.10      0.16        29
# UrinaryBladder       0.81      0.95      0.87       118
#
#       accuracy                           0.78       147
#      macro avg       0.57      0.53      0.52       147
#   weighted avg       0.72      0.78      0.73       147
#
#
#
# Random Forest's accuracy: 78.2%
# LightGBM's accuracy: 80.30000000000001%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.80      1.00      0.89       118
#
#       accuracy                           0.80       147
#      macro avg       0.40      0.50      0.45       147
#   weighted avg       0.64      0.80      0.71       147
#
#
#
# LightGBM's accuracy: 80.30000000000001%
# For 6 features:
# Decision tree's accuracy: 77.60000000000001%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.80      0.97      0.87       118
#
#       accuracy                           0.78       147
#      macro avg       0.40      0.48      0.44       147
#   weighted avg       0.64      0.78      0.70       147
#
#
#
# Decision tree's accuracy: 77.60000000000001%
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest's accuracy: 80.30000000000001%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.50      0.07      0.12        29
# UrinaryBladder       0.81      0.98      0.89       118
#
#       accuracy                           0.80       147
#      macro avg       0.66      0.53      0.51       147
#   weighted avg       0.75      0.80      0.74       147
#
#
#
# Random Forest's accuracy: 80.30000000000001%
# LightGBM's accuracy: 80.30000000000001%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.80      1.00      0.89       118
#
#       accuracy                           0.80       147
#      macro avg       0.40      0.50      0.45       147
#   weighted avg       0.64      0.80      0.71       147
#
#
#
# LightGBM's accuracy: 80.30000000000001%
# For 7 features:
# Decision tree's accuracy: 76.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.79      0.95      0.86       118
#
#       accuracy                           0.76       147
#      macro avg       0.40      0.47      0.43       147
#   weighted avg       0.64      0.76      0.69       147
#
#
#
# Decision tree's accuracy: 76.2%
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest's accuracy: 78.9%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.25      0.03      0.06        29
# UrinaryBladder       0.80      0.97      0.88       118
#
#       accuracy                           0.79       147
#      macro avg       0.53      0.50      0.47       147
#   weighted avg       0.69      0.79      0.72       147
#
#
#
# Random Forest's accuracy: 78.9%
# LightGBM's accuracy: 80.30000000000001%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.80      1.00      0.89       118
#
#       accuracy                           0.80       147
#      macro avg       0.40      0.50      0.45       147
#   weighted avg       0.64      0.80      0.71       147
#
#
#
# LightGBM's accuracy: 80.30000000000001%
# For 8 features:
# Decision tree's accuracy: 76.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.79      0.95      0.86       118
#
#       accuracy                           0.76       147
#      macro avg       0.40      0.47      0.43       147
#   weighted avg       0.64      0.76      0.69       147
#
#
#
# Decision tree's accuracy: 76.2%
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest's accuracy: 79.60000000000001%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.33      0.03      0.06        29
# UrinaryBladder       0.81      0.98      0.89       118
#
#       accuracy                           0.80       147
#      macro avg       0.57      0.51      0.47       147
#   weighted avg       0.71      0.80      0.72       147
#
#
#
# Random Forest's accuracy: 79.60000000000001%
# LightGBM's accuracy: 80.30000000000001%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.00      0.00      0.00        29
# UrinaryBladder       0.80      1.00      0.89       118
#
#       accuracy                           0.80       147
#      macro avg       0.40      0.50      0.45       147
#   weighted avg       0.64      0.80      0.71       147
#
#
#
# LightGBM's accuracy: 80.30000000000001%
# For 9 features:
# Decision tree's accuracy: 91.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.76      0.77        29
# UrinaryBladder       0.94      0.95      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.86      0.85      0.86       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# Decision tree's accuracy: 91.2%
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest's accuracy: 89.1%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.55      0.67        29
# UrinaryBladder       0.90      0.97      0.93       118
#
#       accuracy                           0.89       147
#      macro avg       0.87      0.76      0.80       147
#   weighted avg       0.89      0.89      0.88       147
#
#
#
# Random Forest's accuracy: 89.1%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 10 features:
# Decision tree's accuracy: 90.5%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.76      0.76      0.76        29
# UrinaryBladder       0.94      0.94      0.94       118
#
#       accuracy                           0.90       147
#      macro avg       0.85      0.85      0.85       147
#   weighted avg       0.90      0.90      0.90       147
#
#
#
# Decision tree's accuracy: 90.5%
# Random Forest's accuracy: 89.8%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.85      0.59      0.69        29
# UrinaryBladder       0.91      0.97      0.94       118
#
#       accuracy                           0.90       147
#      macro avg       0.88      0.78      0.82       147
#   weighted avg       0.89      0.90      0.89       147
#
#
#
# Random Forest's accuracy: 89.8%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 11 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 88.4%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.88      0.48      0.62        29
# UrinaryBladder       0.89      0.98      0.93       118
#
#       accuracy                           0.88       147
#      macro avg       0.88      0.73      0.78       147
#   weighted avg       0.88      0.88      0.87       147
#
#
#
# Random Forest's accuracy: 88.4%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 12 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 89.1%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.93      0.48      0.64        29
# UrinaryBladder       0.89      0.99      0.94       118
#
#       accuracy                           0.89       147
#      macro avg       0.91      0.74      0.79       147
#   weighted avg       0.90      0.89      0.88       147
#
#
#
# Random Forest's accuracy: 89.1%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 13 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 89.1%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.93      0.48      0.64        29
# UrinaryBladder       0.89      0.99      0.94       118
#
#       accuracy                           0.89       147
#      macro avg       0.91      0.74      0.79       147
#   weighted avg       0.90      0.89      0.88       147
#
#
#
# Random Forest's accuracy: 89.1%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 14 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 88.4%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.93      0.45      0.60        29
# UrinaryBladder       0.88      0.99      0.93       118
#
#       accuracy                           0.88       147
#      macro avg       0.90      0.72      0.77       147
#   weighted avg       0.89      0.88      0.87       147
#
#
#
# Random Forest's accuracy: 88.4%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 15 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 87.8%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.92      0.41      0.57        29
# UrinaryBladder       0.87      0.99      0.93       118
#
#       accuracy                           0.88       147
#      macro avg       0.90      0.70      0.75       147
#   weighted avg       0.88      0.88      0.86       147
#
#
#
# Random Forest's accuracy: 87.8%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 16 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 89.1%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.88      0.52      0.65        29
# UrinaryBladder       0.89      0.98      0.94       118
#
#       accuracy                           0.89       147
#      macro avg       0.89      0.75      0.79       147
#   weighted avg       0.89      0.89      0.88       147
#
#
#
# Random Forest's accuracy: 89.1%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 17 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 87.8%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.92      0.41      0.57        29
# UrinaryBladder       0.87      0.99      0.93       118
#
#       accuracy                           0.88       147
#      macro avg       0.90      0.70      0.75       147
#   weighted avg       0.88      0.88      0.86       147
#
#
#
# Random Forest's accuracy: 87.8%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 18 features:
# Decision tree's accuracy: 91.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.77      0.79      0.78        29
# UrinaryBladder       0.95      0.94      0.94       118
#
#       accuracy                           0.91       147
#      macro avg       0.86      0.87      0.86       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# Decision tree's accuracy: 91.2%
# Random Forest's accuracy: 89.1%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.88      0.52      0.65        29
# UrinaryBladder       0.89      0.98      0.94       118
#
#       accuracy                           0.89       147
#      macro avg       0.89      0.75      0.79       147
#   weighted avg       0.89      0.89      0.88       147
#
#
#
# Random Forest's accuracy: 89.1%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 19 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 89.1%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.93      0.48      0.64        29
# UrinaryBladder       0.89      0.99      0.94       118
#
#       accuracy                           0.89       147
#      macro avg       0.91      0.74      0.79       147
#   weighted avg       0.90      0.89      0.88       147
#
#
#
# Random Forest's accuracy: 89.1%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 20 features:
# Decision tree's accuracy: 91.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.77      0.79      0.78        29
# UrinaryBladder       0.95      0.94      0.94       118
#
#       accuracy                           0.91       147
#      macro avg       0.86      0.87      0.86       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# Decision tree's accuracy: 91.2%
# Random Forest's accuracy: 88.4%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.93      0.45      0.60        29
# UrinaryBladder       0.88      0.99      0.93       118
#
#       accuracy                           0.88       147
#      macro avg       0.90      0.72      0.77       147
#   weighted avg       0.89      0.88      0.87       147
#
#
#
# Random Forest's accuracy: 88.4%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 21 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 87.8%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.92      0.41      0.57        29
# UrinaryBladder       0.87      0.99      0.93       118
#
#       accuracy                           0.88       147
#      macro avg       0.90      0.70      0.75       147
#   weighted avg       0.88      0.88      0.86       147
#
#
#
# Random Forest's accuracy: 87.8%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 22 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 87.8%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.92      0.41      0.57        29
# UrinaryBladder       0.87      0.99      0.93       118
#
#       accuracy                           0.88       147
#      macro avg       0.90      0.70      0.75       147
#   weighted avg       0.88      0.88      0.86       147
#
#
#
# Random Forest's accuracy: 87.8%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 23 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 85.0%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.89      0.28      0.42        29
# UrinaryBladder       0.85      0.99      0.91       118
#
#       accuracy                           0.85       147
#      macro avg       0.87      0.63      0.67       147
#   weighted avg       0.86      0.85      0.82       147
#
#
#
# Random Forest's accuracy: 85.0%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 24 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 86.4%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.91      0.34      0.50        29
# UrinaryBladder       0.86      0.99      0.92       118
#
#       accuracy                           0.86       147
#      macro avg       0.88      0.67      0.71       147
#   weighted avg       0.87      0.86      0.84       147
#
#
#
# Random Forest's accuracy: 86.4%
# LightGBM's accuracy: 91.2%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.81      0.72      0.76        29
# UrinaryBladder       0.93      0.96      0.95       118
#
#       accuracy                           0.91       147
#      macro avg       0.87      0.84      0.85       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# LightGBM's accuracy: 91.2%
# For 25 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 87.8%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.92      0.41      0.57        29
# UrinaryBladder       0.87      0.99      0.93       118
#
#       accuracy                           0.88       147
#      macro avg       0.90      0.70      0.75       147
#   weighted avg       0.88      0.88      0.86       147
#
#
#
# Random Forest's accuracy: 87.8%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 26 features:
# Decision tree's accuracy: 91.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.77      0.79      0.78        29
# UrinaryBladder       0.95      0.94      0.94       118
#
#       accuracy                           0.91       147
#      macro avg       0.86      0.87      0.86       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# Decision tree's accuracy: 91.2%
# Random Forest's accuracy: 86.4%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.91      0.34      0.50        29
# UrinaryBladder       0.86      0.99      0.92       118
#
#       accuracy                           0.86       147
#      macro avg       0.88      0.67      0.71       147
#   weighted avg       0.87      0.86      0.84       147
#
#
#
# Random Forest's accuracy: 86.4%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 27 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 85.7%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.83      0.34      0.49        29
# UrinaryBladder       0.86      0.98      0.92       118
#
#       accuracy                           0.86       147
#      macro avg       0.85      0.66      0.70       147
#   weighted avg       0.85      0.86      0.83       147
#
#
#
# Random Forest's accuracy: 85.7%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 28 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 87.1%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.92      0.38      0.54        29
# UrinaryBladder       0.87      0.99      0.92       118
#
#       accuracy                           0.87       147
#      macro avg       0.89      0.69      0.73       147
#   weighted avg       0.88      0.87      0.85       147
#
#
#
# Random Forest's accuracy: 87.1%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 29 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 86.4%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.91      0.34      0.50        29
# UrinaryBladder       0.86      0.99      0.92       118
#
#       accuracy                           0.86       147
#      macro avg       0.88      0.67      0.71       147
#   weighted avg       0.87      0.86      0.84       147
#
#
#
# Random Forest's accuracy: 86.4%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 30 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 85.7%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.90      0.31      0.46        29
# UrinaryBladder       0.85      0.99      0.92       118
#
#       accuracy                           0.86       147
#      macro avg       0.88      0.65      0.69       147
#   weighted avg       0.86      0.86      0.83       147
#
#
#
# Random Forest's accuracy: 85.7%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 31 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 86.4%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.91      0.34      0.50        29
# UrinaryBladder       0.86      0.99      0.92       118
#
#       accuracy                           0.86       147
#      macro avg       0.88      0.67      0.71       147
#   weighted avg       0.87      0.86      0.84       147
#
#
#
# Random Forest's accuracy: 86.4%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 32 features:
# Decision tree's accuracy: 91.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.77      0.79      0.78        29
# UrinaryBladder       0.95      0.94      0.94       118
#
#       accuracy                           0.91       147
#      macro avg       0.86      0.87      0.86       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# Decision tree's accuracy: 91.2%
# Random Forest's accuracy: 87.1%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.92      0.38      0.54        29
# UrinaryBladder       0.87      0.99      0.92       118
#
#       accuracy                           0.87       147
#      macro avg       0.89      0.69      0.73       147
#   weighted avg       0.88      0.87      0.85       147
#
#
#
# Random Forest's accuracy: 87.1%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 33 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 83.7%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.86      0.21      0.33        29
# UrinaryBladder       0.84      0.99      0.91       118
#
#       accuracy                           0.84       147
#      macro avg       0.85      0.60      0.62       147
#   weighted avg       0.84      0.84      0.79       147
#
#
#
# Random Forest's accuracy: 83.7%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 34 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 85.7%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.90      0.31      0.46        29
# UrinaryBladder       0.85      0.99      0.92       118
#
#       accuracy                           0.86       147
#      macro avg       0.88      0.65      0.69       147
#   weighted avg       0.86      0.86      0.83       147
#
#
#
# Random Forest's accuracy: 85.7%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 35 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 84.39999999999999%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.88      0.24      0.38        29
# UrinaryBladder       0.84      0.99      0.91       118
#
#       accuracy                           0.84       147
#      macro avg       0.86      0.62      0.64       147
#   weighted avg       0.85      0.84      0.81       147
#
#
#
# Random Forest's accuracy: 84.39999999999999%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 36 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 84.39999999999999%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.88      0.24      0.38        29
# UrinaryBladder       0.84      0.99      0.91       118
#
#       accuracy                           0.84       147
#      macro avg       0.86      0.62      0.64       147
#   weighted avg       0.85      0.84      0.81       147
#
#
#
# Random Forest's accuracy: 84.39999999999999%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 37 features:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%
# Random Forest's accuracy: 85.0%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.89      0.28      0.42        29
# UrinaryBladder       0.85      0.99      0.91       118
#
#       accuracy                           0.85       147
#      macro avg       0.87      0.63      0.67       147
#   weighted avg       0.86      0.85      0.82       147
#
#
#
# Random Forest's accuracy: 85.0%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%
# For 38 features:
# Decision tree's accuracy: 91.2%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.77      0.79      0.78        29
# UrinaryBladder       0.95      0.94      0.94       118
#
#       accuracy                           0.91       147
#      macro avg       0.86      0.87      0.86       147
#   weighted avg       0.91      0.91      0.91       147
#
#
#
# Decision tree's accuracy: 91.2%
# Random Forest's accuracy: 85.0%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.89      0.28      0.42        29
# UrinaryBladder       0.85      0.99      0.91       118
#
#       accuracy                           0.85       147
#      macro avg       0.87      0.63      0.67       147
#   weighted avg       0.86      0.85      0.82       147
#
#
#
# Random Forest's accuracy: 85.0%
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%

# %%
X_values = [i for i in range(2, len(X.columns))]

N = len(X_values)
ind = np.arange(N)
width = 0.28

plt.figure(figsize=(60, 30))

bar1 = plt.bar(ind, dt_val, width, color='r')
bar2 = plt.bar(ind+width, rf_val, width, color='g')
bar3 = plt.bar(ind+width*2, lgbtm_val, width, color='b')

plt.title("Principal Component Analysis", fontsize=25)
plt.xticks(ind+width, X_values, fontsize=20)
plt.yticks(np.arange(0, 105, 5), fontsize=20)
plt.xlabel("Number of extracted features", fontsize=20)
plt.ylabel("Performance measure: Accuracy(%)", fontsize=20)

plt.show()

# %%
X_pca = pca(X, 11)
X_train, X_test, Y_train, Y_test = splitting(X_pca, Y)

_, _, Y_pred_proba_dt, _ = Decision_tree(X_train, Y_train, Y_test, classes)
positive_probs_dt = Y_pred_proba_dt[:,1]
# Out:
# Decision tree's accuracy: 91.8%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.79      0.79      0.79        29
# UrinaryBladder       0.95      0.95      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.87      0.87      0.87       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# Decision tree's accuracy: 91.8%

# %%
X_pca = pca(X, 10)
X_train, X_test, Y_train, Y_test = splitting(X_pca, Y)

_, _, Y_pred_proba_rf, _ = Random_forest(X_train, Y_train, Y_test, classes)
positive_probs_rf = Y_pred_proba_rf[:,1]
# Out:
# Random Forest's accuracy: 89.8%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.85      0.59      0.69        29
# UrinaryBladder       0.91      0.97      0.94       118
#
#       accuracy                           0.90       147
#      macro avg       0.88      0.78      0.82       147
#   weighted avg       0.89      0.90      0.89       147
#
#
#
# Random Forest's accuracy: 89.8%

# %%
X_pca = pca(X, 25)
X_train, X_test, Y_train, Y_test = splitting(X_pca, Y)

_, _, Y_pred_proba_lgbtm, _ = Lgbtm(X_train, Y_train, Y_test, classes)
positive_probs_lgbtm = Y_pred_proba_lgbtm[:,1]
# Out:
# LightGBM's accuracy: 91.8%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.84      0.72      0.78        29
# UrinaryBladder       0.93      0.97      0.95       118
#
#       accuracy                           0.92       147
#      macro avg       0.89      0.85      0.86       147
#   weighted avg       0.92      0.92      0.92       147
#
#
#
# LightGBM's accuracy: 91.8%

# %%
roc_auc(Y_test, positive_probs_dt, positive_probs_rf, positive_probs_lgbtm)

# %% [markdown]
# ## **`Linear Discriminant Analysis (LDA)`**

# %%
def lda(X, Y):
  from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
  lds = LDA() 
  lds.fit(X, Y)
  X_lda = lds.transform(X)  
  return X_lda

# %%
X_lda = lda(X, Y)
X_train, X_test, Y_train, Y_test = splitting(X_lda, Y)

# %%
_, Y_pred_dt, Y_pred_proba_dt, _ = Decision_tree(X_train, Y_train, Y_test, classes)
positive_probs_dt = Y_pred_proba_dt[:,1]
# Out:
# Decision tree's accuracy: 83.0%
#
#
# Decision tree's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.75      0.21      0.32        29
# UrinaryBladder       0.83      0.98      0.90       118
#
#       accuracy                           0.83       147
#      macro avg       0.79      0.59      0.61       147
#   weighted avg       0.82      0.83      0.79       147
#
#
#
# Decision tree's accuracy: 83.0%

# %%
_, Y_pred_dt, Y_pred_proba_dt, _ = Random_forest(X_train, Y_train, Y_test, classes)
positive_probs_rf = Y_pred_proba_dt[:,1]
# Out:
# Random Forest's accuracy: 70.1%
#
#
# Random Forest's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.22      0.21      0.21        29
# UrinaryBladder       0.81      0.82      0.82       118
#
#       accuracy                           0.70       147
#      macro avg       0.52      0.51      0.51       147
#   weighted avg       0.69      0.70      0.70       147
#
#
#
# Random Forest's accuracy: 70.1%

# %%
_, Y_pred_dt, Y_pred_proba_dt, _ = Lgbtm(X_train, Y_train, Y_test, classes)
positive_probs_rf = Y_pred_proba_dt[:,1]
# Out:
# LightGBM's accuracy: 83.0%
#
#
# LightGBM's classification report:
#                 precision    recall  f1-score   support
#
#       Cystitis       0.70      0.24      0.36        29
# UrinaryBladder       0.84      0.97      0.90       118
#
#       accuracy                           0.83       147
#      macro avg       0.77      0.61      0.63       147
#   weighted avg       0.81      0.83      0.79       147
#
#
#
# LightGBM's accuracy: 83.0%

# %%
roc_auc(Y_test, positive_probs_dt, positive_probs_rf, positive_probs_lgbtm)
